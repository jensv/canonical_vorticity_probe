# %%
import mst_mach_220927 as mst
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
sns.set_context('poster')

# %%
from importlib import reload
reload(mst)
# Out:
# <module 'mst_mach_220927' from '/home/reksoatr/canonical_vorticity_probe/tetra/mst_mach_220927.py'>

# %%
mst.mach_results??

# %%
mst.plot_mach_results??

# %%
plt.figure(figsize=(10, 15))
mst.plot_mach_results(res='isat', shot=1220927065, second_shot=None, ylim=(-0.1, 0.1))

# %%
plt.figure(figsize=(10, 7))
mst.plot_mach_results(res='isat', shot=1220927077, second_shot=None)

# %%
plt.figure(figsize=(10, 7))
mst.plot_mach_results(res='isat', shot=1220927065, 
                      second_shot=1220927077, tetra_missing_tip=4, merge_method='first')
# Out:
# shot 1 missng a
# shot 2 missing c
# first replace a
# other copies b
# other copies c
# other copies d
# other copies ret

# %%
plt.figure(figsize=(10, 15))
mst.plot_mach_results(res='isat', shot=1220927065, 
                      second_shot=1220927077, tetra_missing_tip=4,
                      merge_method='second')

# %%
plt.figure(figsize=(10, 15))
mst.plot_mach_results(res='isat', shot=1220927065, 
                      second_shot=1220927077, tetra_missing_tip=4,
                      merge_method='second', ylim=(-0.01, 0.05))

# %%
plt.figure(figsize=(10, 7))
mst.plot_mach_results(res='rat', shot=1220927065, 
                      second_shot=1220927077, tetra_missing_tip=4, merge_method='first', delphi=0)
# Out:
# shot 1 missng a
# shot 2 missing c
# first replace a
# other copies b
# other copies c
# other copies d
# other copies ret

# %%
plt.figure(figsize=(10, 7))
mst.plot_mach_results(res='mach', shot=1220927065, 
                      second_shot=1220927077, tetra_missing_tip=4, merge_method='first', delphi=180)
# Out:
# shot 1 missng a
# shot 2 missing c
# first replace a
# other copies b
# other copies c
# other copies d
# other copies ret

# %%
plt.figure(figsize=(10, 7))
mst.plot_mach_results(res='mach', shot=1220927055, 
                      second_shot=1220928050, tetra_missing_tip=4, tmax=0.05, merge_method='second', delphi=0)
# Out:
# shot 1 missng a
# shot 2 missing c
# other copies a
# other copies b
# second replace c
# other copies d
# other copies ret

# %%
fig = plt.figure(figsize=(10, 7))
mst.plot_mach_results(res='mach', shot=1220927055, 
                      second_shot=1220928050, tetra_missing_tip=4, tmin=0, tmax=0.1, merge_method='second', delphi=0)
for ax in fig.axes:
    ax.set_ylim(-0.1, 0.1)
plt.show()

# %%
fig.axes[0].set_ylim()
# Out:
# (0.6859053761345786, 3.5891337899589084)
